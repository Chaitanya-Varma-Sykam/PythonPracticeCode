# %%
from IPython.display import clear_output
winner=0
def sss(val,mem):
    if val==1:
        l1[1]=mem
    elif val==2:
        l1[5]=mem
    elif val==3:
        l1[9]=mem
    elif val==4:
        l2[1]=mem
    elif val==5:
        l2[5]=mem
    elif val==6:
        l2[9]=mem
    elif val==7:
        l3[1]=mem
    elif val==8:
        l3[5]=mem
    elif val==9:
        l3[9]=mem
    if (l1[1]==l1[5]==l1[9]==mem) or (l2[1]==l2[5]==l2[9]==mem) or (l3[1]==l3[5]==l3[9]==mem) or (l1[1]==l2[1]==l3[1]==mem)or (l1[5]==l2[5]==l3[5]==mem)or(l1[9]==l2[9]==l3[9]==mem)or (l1[1]==l2[5]==l3[9]==mem)or(l1[9]==l2[5]==l3[1]==mem):
        global winner
        winner = 1
        return print(f'*****GAME_OVER***** \n$$ PLAYER {mem} WON THE GAME $$')
#def tictac()
l1=['_','_','_','|','_','_','_','|','_','_','_']
l2=['_','_','_','|','_','_','_','|','_','_','_']
l3=[' ',' ',' ','|',' ',' ',' ','|',' ',' ',' ']
game=''.join(l1)+'\n'+''.join(l2)+'\n'+''.join(l3)
print('HI')
print(game)
repeat=''
t=1

while len(repeat)<9:
    if winner==1:
        break
    place=0
    if t==1:
        print('Lets start the game\n')
    if t%2==0:
        print("OOOOOO's TURN: Enter a value between 1 to 9")
        place=int(input())
        if str(place) not in repeat:
            print(f'place is NOT in repeat-{place}')
            clear_output(wait=True)
            sss(place,'O')
        else:
            while str(place) in repeat:
                print('place occupied please enter another value:')
                place=int(input())
                clear_output(wait=True)
                sss(place,'O')
                t=t+1
                pass
            
    else:
        print("XXXXXX's TURN: Enter a value between 1 to 9")
        place=int(input())
        if str(place) not in repeat:
            print(f'place is not in repeat-{place}')
            clear_output(wait=True)
            sss(place,'X')
        else:
            while str(place) in repeat:
                print('place occupied please enter another value:')
                place=int(input())
                clear_output(wait=True)
                sss(place,'X')
                t=t+1
                pass
            
    game=''.join(l1)+'\n'+''.join(l2)+'\n'+''.join(l3)   
    print(game)
    repeat=repeat+(str(place))
    t+=1
    
if len(repeat)==9:
    print('\n GAME IS COMPLETED-BE HAPPY')
# Out:
# *****GAME_OVER*****
# $$ PLAYER X WON THE GAME $$
# _X_|_O_|_X_
# _X_|_X_|_O_
#  O | O | X
#
#  GAME IS COMPLETED-BE HAPPY
